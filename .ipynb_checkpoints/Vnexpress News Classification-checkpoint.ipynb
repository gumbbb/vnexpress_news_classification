# %% [markdown]
# # Project: Vnexpress News Classification
#     Sau khi crawl dữ liệu từ web vnexpress, được tập dataset gồm 6000 bài báo. Ở project này, thực hiện xây dựng mô hình máy học để phân loại báo

# %% [markdown]
# ### I. Import thư viện cần thiết

# %%
#import lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import underthesea
import regex as re
from underthesea import word_tokenize

# %%
train_df=pd.read_csv("./data/data.csv")
train_df = train_df.drop("Unnamed: 0", axis =  1)
train_df
# Out:
#            Tag                                            Content
# 0     Thể thao  Mbappe không muốn rời PSG hè này vì tiếc 163 t...
# 1     Thể thao  Thanh Hóa bị cầm chân ở Nam ĐịnhSau khi thua C...
# 2     Thể thao  Quang Hải được biệt đãi thế nào ở CAHNNguyễn Q...
# 3     Thể thao  Messi thừa nhận rạn nứt với fan PSGTrên tờ AS ...
# 4     Thể thao  Mỹ đăng cai FIFA Club World Cup 2025Theo thông...
# ...        ...                                                ...
# 5898  Giải trí  Hôm 9/6, Nicola Peltz "mặc như không" khi đi ă...
# 5899  Giải trí  Chiều 15/6, trong buổi họp báo định kỳ, đại di...
# 5900  Giải trí  Tại lễ trao giải Tony hôm 11/6, diễn viên Lupi...
# 5901  Giải trí  Châu Diệu Minh là em dâu ca sĩ - diễn viên Min...
# 5902  Giải trí  Đam mê thời trang, Thảo Nhi còn thành lập thươ...
#
# [5903 rows x 2 columns]

# %% [markdown]
# ### II. Data Preprocessing
# #### Chuẩn hóa unicode, loại bỏ html code

# %%
uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"
 
def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic
dicchar = loaddicchar()

# Hàm chuyển Unicode dựng sẵn về Unicde tổ hợp (phổ biến hơn)
def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

bang_nguyen_am = [['a', 'à', 'á', 'ả', 'ã', 'ạ', 'a'],
                  ['ă', 'ằ', 'ắ', 'ẳ', 'ẵ', 'ặ', 'aw'],
                  ['â', 'ầ', 'ấ', 'ẩ', 'ẫ', 'ậ', 'aa'],
                  ['e', 'è', 'é', 'ẻ', 'ẽ', 'ẹ', 'e'],
                  ['ê', 'ề', 'ế', 'ể', 'ễ', 'ệ', 'ee'],
                  ['i', 'ì', 'í', 'ỉ', 'ĩ', 'ị', 'i'],
                  ['o', 'ò', 'ó', 'ỏ', 'õ', 'ọ', 'o'],
                  ['ô', 'ồ', 'ố', 'ổ', 'ỗ', 'ộ', 'oo'],
                  ['ơ', 'ờ', 'ớ', 'ở', 'ỡ', 'ợ', 'ow'],
                  ['u', 'ù', 'ú', 'ủ', 'ũ', 'ụ', 'u'],
                  ['ư', 'ừ', 'ứ', 'ử', 'ữ', 'ự', 'uw'],
                  ['y', 'ỳ', 'ý', 'ỷ', 'ỹ', 'ỵ', 'y']]
bang_ky_tu_dau = ['', 'f', 's', 'r', 'x', 'j']

nguyen_am_to_ids = {}

for i in range(len(bang_nguyen_am)):
    for j in range(len(bang_nguyen_am[i]) - 1):
        nguyen_am_to_ids[bang_nguyen_am[i][j]] = (i, j)

def chuan_hoa_dau_tu_tieng_viet(word):
    if not is_valid_vietnam_word(word):
        return word

    chars = list(word)
    dau_cau = 0
    nguyen_am_index = []
    qu_or_gi = False
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x == -1:
            continue
        elif x == 9:  # check qu
            if index != 0 and chars[index - 1] == 'q':
                chars[index] = 'u'
                qu_or_gi = True
        elif x == 5:  # check gi
            if index != 0 and chars[index - 1] == 'g':
                chars[index] = 'i'
                qu_or_gi = True
        if y != 0:
            dau_cau = y
            chars[index] = bang_nguyen_am[x][0]
        if not qu_or_gi or index != 1:
            nguyen_am_index.append(index)
    if len(nguyen_am_index) < 2:
        if qu_or_gi:
            if len(chars) == 2:
                x, y = nguyen_am_to_ids.get(chars[1])
                chars[1] = bang_nguyen_am[x][dau_cau]
            else:
                x, y = nguyen_am_to_ids.get(chars[2], (-1, -1))
                if x != -1:
                    chars[2] = bang_nguyen_am[x][dau_cau]
                else:
                    chars[1] = bang_nguyen_am[5][dau_cau] if chars[1] == 'i' else bang_nguyen_am[9][dau_cau]
            return ''.join(chars)
        return word

    for index in nguyen_am_index:
        x, y = nguyen_am_to_ids[chars[index]]
        if x == 4 or x == 8:  # ê, ơ
            chars[index] = bang_nguyen_am[x][dau_cau]
            # for index2 in nguyen_am_index:
            #     if index2 != index:
            #         x, y = nguyen_am_to_ids[chars[index]]
            #         chars[index2] = bang_nguyen_am[x][0]
            return ''.join(chars)

    if len(nguyen_am_index) == 2:
        if nguyen_am_index[-1] == len(chars) - 1:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
            chars[nguyen_am_index[0]] = bang_nguyen_am[x][dau_cau]
            # x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
            # chars[nguyen_am_index[1]] = bang_nguyen_am[x][0]
        else:
            # x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
            # chars[nguyen_am_index[0]] = bang_nguyen_am[x][0]
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
            chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    else:
        # x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
        # chars[nguyen_am_index[0]] = bang_nguyen_am[x][0]
        x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
        chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
        # x, y = nguyen_am_to_ids[chars[nguyen_am_index[2]]]
        # chars[nguyen_am_index[2]] = bang_nguyen_am[x][0]
    return ''.join(chars)


def is_valid_vietnam_word(word):
    chars = list(word)
    nguyen_am_index = -1
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x != -1:
            if nguyen_am_index == -1:
                nguyen_am_index = index
            else:
                if index - nguyen_am_index != 1:
                    return False
                nguyen_am_index = index
    return True


def chuan_hoa_dau_cau_tieng_viet(sentence):
    """
        Chuyển câu tiếng việt về chuẩn gõ dấu kiểu cũ.
        :param sentence:
        :return:
        """
    sentence = sentence.lower()
    words = sentence.split()
    for index, word in enumerate(words):
        cw = re.sub(r'(^\p{P}*)([p{L}.]*\p{L}+)(\p{P}*$)', r'\1/\2/\3', word).split('/')
        # print(cw)
        if len(cw) == 3:
            cw[1] = chuan_hoa_dau_tu_tieng_viet(cw[1])
        words[index] = ''.join(cw)
    return ' '.join(words)

def remove_html(txt):
    return re.sub(r'<[^>]*>', '', txt)

# %%
labels = list(set(train_df['Tag'].tolist()))
texts = train_df['Content'].tolist()
tags = train_df['Tag'].tolist()

# %%
def text_preprocess(document):
    # xóa html code
    document = remove_html(document)
    # chuẩn hóa unicode
    document = convert_unicode(document)
    # chuẩn hóa cách gõ dấu tiếng Việt
    document = chuan_hoa_dau_cau_tieng_viet(document)
    # tách từ
    document = word_tokenize(document, format="text")
    # đưa về lower
    document = document.lower()
    # xóa các ký tự không cần thiết
    document = re.sub(r'[^\s\wáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ_]',' ',document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    return document
for text in texts:
    text = text_preprocess(text)
texts
hồi giữa tháng Năm. Seyboth Wild, sau khi hạ Medvedev, sẽ gặp Guido Pella ở vòng kế tiếp. Tay vợt Brazil nói rằng anh hạ được hạt giống số hai nhờ việc tấn công tốt ở cú thuận tay và tràn lưới mỗi khi có cơ hội. "Tôi xem Medvedev thi đấu trong suốt thời trẻ", Seyboth Wild nói về đàn anh. "Được bước ra sân đấu này, đánh bại anh ấy quả là một giấc mơ thành sự thật". Vy Anh',
#  ...]

# %% [markdown]
# Số lượng label

# %%
label_counts = {}
for label in tags:
    if label in label_counts:
        label_counts[label] += 1
    else:
        label_counts[label] = 1
label_counts
# Out:
# {'Thể thao': 1665,
#  'Thời sự': 320,
#  'Thế giới': 342,
#  'Kinh tế': 1005,
#  'Khoa học': 980,
#  'Giải trí': 1591}

# %% [markdown]
# Tìm ra những từ sử dụng nhiều nhất, có thể là stopword
# *stopword là từ mà không có ý nghĩa cho việc xây dựng mô hình máy học

# %%
import string
word_counts = {}
for text in texts:
    # Remove punctuation and convert text to lowercase
    text = text.translate(str.maketrans("", "", string.punctuation)).lower()
    # Split text into words
    words = word_tokenize(text)
    # Count word occurrences
    for word in words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
word_counts = sorted(word_counts.items(), key=lambda x: x[1],reverse = True)
word_counts
# Out:
# [('và', 47062),
#  ('của', 38155),
#  ('trong', 31892),
#  ('các', 27547),
#  ('là', 27102),
#  ('với', 26961),
#  ('cho', 25763),
#  ('có', 22094),
#  ('được', 21473),
#  ('ở', 20441),
#  ('năm', 20083),
#  ('khi', 19877),
#  ('một', 18880),
#  ('không', 18399),
#  ('người', 16234),
#  ('để', 15998),
#  ('từ', 14979),
#  ('những', 14721),
#  ('này', 14342),
#  ('nhiều', 13980),
#  ('đã', 12891),
#  ('anh', 12694),
#  ('vào', 12692),
#  ('về', 12652),
#  ('đó', 12535),
#  ('sau', 12443),
#  ('tại', 12280),
#  ('tôi', 12232),
#  ('đến', 11802),
#  ('trên', 11536),
#  ('sẽ', 11179),
#  ('hơn', 11120),
#  ('ông', 11087),
#  ('cũng', 11034),
#  ('theo', 10950),
#  ('hai', 10854),
#  ('như', 9440),
#  ('ra', 9246),
#  ('trước', 8846),
#  ('nhưng', 8616),
#  ('nói', 8186),
#  ('nhất', 8170),
#  ('nam', 8000),
#  ('tháng', 7733),
#  ('có thể', 7573),
#  ('biết', 7321),
#  ('việt', 7294),
#  ('còn', 7124),
#  ('phải', 6750),
#  ('lại', 6658),
#  ('ngày', 6492),
#  ('nhà', 6477),
#  ('họ', 6473),
#  ('làm', 6461),
#  ('qua', 6313),
#  ('đang', 6232),
#  ('chỉ', 6161),
#  ('lần', 6121),
#  ('việc', 5918),
#  ('cùng', 5772),
#  ('bị', 5664),
#  ('đây', 5639),
#  ('sự', 5638),
#  ('phim', 5526),
#  ('nước', 5524),
#  ('mới', 5523),
#  ('giải', 5512),
#  ('trận', 5392),
#  ('cao', 5109),
#  ('lớn', 5085),
#  ('tới', 4997),
#  ('đầu', 4944),
#  ('lên', 4921),
#  ('cô', 4903),
#  ('mỹ', 4825),
#  ('do', 4787),
#  ('từng', 4778),
#  ('ba', 4762),
#  ('đi', 4753),
#  ('tuổi', 4747),
#  ('rằng', 4729),
#  ('thứ', 4526),
#  ('khác', 4486),
#  ('usd', 4459),
#  ('gần', 4342),
#  ('tăng', 4299),
#  ('vẫn', 4174),
#  ('bộ', 4130),
#  ('vì', 4051),
#  ('hay', 3840),
#  ('triệu', 3780),
#  ('nghiên cứu', 3683),
#  ('công ty', 3670),
#  ('rất', 3648),
#  ('giúp', 3622),
#  ('nhóm', 3609),
#  ('giảm', 3567),
#  ('đồng', 3563),
#  ('bằng', 3441),
#  ('tạo', 3409),
#  ('cuộc', 3400),
#  ('cả', 3393),
#  ('chưa', 3382),
#  ('thấy', 3380),
#  ('cách', 3374),
#  ('tỷ', 3363),
#  ('điều', 3335),
#  ('thế giới', 3321),
#  ('cần', 3294),
#  ('khiến', 3272),
#  ('mà', 3240),
#  ('công nghệ', 3216),
#  ('nay', 3187),
#  ('con', 3166),
#  ('thêm', 3119),
#  ('nhận', 3114),
#  ('đường', 3087),
#  ('phát triển', 3071),
#  ('số', 3018),
#  ('muốn', 3016),
#  ('bên', 2993),
#  ('thời gian', 2991),
#  ('chạy', 2985),
#  ('nếu', 2903),
#  ('đầu tiên', 2874),
#  ('đội', 2862),
#  ('khoảng', 2855),
#  ('phút', 2814),
#  ('tổ chức', 2788),
#  ('đầu tư', 2757),
#  ('tốt', 2736),
#  ('mỗi', 2728),
#  ('đưa', 2724),
#  ('tuy nhiên', 2711),
#  ('hàng', 2708),
#  ('giá', 2707),
#  ('nên', 2703),
#  ('điểm', 2690),
#  ('trung quốc', 2667),
#  ('mùa', 2654),
#  ('thị trường', 2640),
#  ('vòng', 2638),
#  ('10', 2569),
#  ('5', 2549),
#  ('so', 2526),
#  ('thắng', 2515),
#  ('một số', 2510),
#  ('tiền', 2505),
#  ('hoạt động', 2504),
#  ('mình', 2489),
#  ('đấu', 2488),
#  ('sử dụng', 2471),
#  ('cuối', 2464),
#  ('chúng tôi', 2459),
#  ('gặp', 2456),
#  ('bóng', 2444),
#  ('mức', 2432),
#  ('ban', 2374),
#  ('giữa', 2358),
#  ('phần', 2353),
#  ('diễn', 2347),
#  ('ấy', 2341),
#  ('hoặc', 2325),
#  ('khoa học', 2312),
#  ('ngoài', 2296),
#  ('hà', 2293),
#  ('dù', 2282),
#  ('diễn viên', 2274),
#  ('sản xuất', 2269),
#  ('hlv', 2248),
#  ('nhau', 2240),
#  ('tiếp tục', 2232),
#  ('đạt', 2229),
#  ('đều', 2216),
#  ('tham gia', 2211),
#  ('gây', 2206),
#  ('đóng', 2194),
#  ('mọi', 2190),
#  ('khả năng', 2183),
#  ('kinh tế', 2182),
#  ('nga', 2178),
#  ('tác phẩm', 2164),
#  ('chính', 2159),
#  ('doanh nghiệp', 2155),
#  ('quốc', 2147),
#  ('km', 2141),
#  ('mang', 2120),
#  ('độ', 2120),
#  ('nào', 2119),
#  ('lúc', 2085),
#  ('3', 2053),
#  ('hiện', 2043),
#  ('marathon', 2038),
#  ('loại', 2026),
#  ('vô địch', 2020),
#  ('trần', 2015),
#  ('4', 2015),
#  ('bạn', 2004),
#  ('bởi', 1998),
#  ('quốc gia', 1989),
#  ('bán', 1978),
#  ('bà', 1973),
#  ('sân', 1971),
#  ('bàn', 1960),
#  ('hôm', 1958),
#  ('sản phẩm', 1946),
#  ('thực hiện', 1940),
#  ('dự án', 1909),
#  ('cầu thủ', 1888),
#  ('đạo diễn', 1887),
#  ('dùng', 1879),
#  ('gì', 1869),
#  ('giờ', 1867),
#  ('the', 1866),
#  ('hệ thống', 1855),
#  ('khán giả', 1850),
#  ('thu', 1849),
#  ('djokovic', 1849),
#  ('tìm', 1845),
#  ('cup', 1844),
#  ('đánh giá', 1839),
#  ('chơi', 1834),
#  ('tên', 1834),
#  ('nơi', 1833),
#  ('hàn', 1833),
#  ('xây dựng', 1827),
#  ('xe', 1821),
#  ('tiếng', 1801),
#  ('tuần', 1795),
#  ('điện', 1789),
#  ('lan', 1778),
#  ('quốc tế', 1772),
#  ('trở thành', 1761),
#  ('dưới', 1759),
#  ('không thể', 1755),
#  ('trẻ', 1747),
#  ('bốn', 1744),
#  ('thuộc', 1744),
#  ('thành', 1738),
#  ('quá', 1735),
#  ('sống', 1724),
#  ('tàu', 1720),
#  ('ngành', 1718),
#  ('man', 1707),
#  ('2023', 1704),
#  ('gia đình', 1701),
#  ('2', 1698),
#  ('giữ', 1690),
#  ('xem', 1678),
#  ('thiết kế', 1675),
#  ('giành', 1674),
#  ('hỗ trợ', 1673),
#  ('tp', 1673),
#  ('kể', 1661),
#  ('mua', 1646),
#  ('tay vợt', 1642),
#  ('vốn', 1640),
#  ('mất', 1638),
#  ('bắt đầu', 1623),
#  ('pháp', 1615),
#  ('thua', 1615),
#  ('nhỏ', 1614),
#  ('20', 1608),
#  ('gồm', 1607),
#  ('luôn', 1596),
#  ('ai', 1594),
#  ('dài', 1587),
#  ('viết', 1583),
#  ('sang', 1570),
#  ('hãng', 1552),
#  ('cơ hội', 1546),
#  ('nhờ', 1545),
#  ('nha', 1543),
#  ('chương trình', 1538),
#  ('xuống', 1534),
#  ('tin', 1530),
#  ('đứng', 1525),
#  ('khu vực', 1514),
#  ('vượt', 1512),
#  ('tính', 1505),
#  ('bài', 1505),
#  ('kết quả', 1497),
#  ('ảnh', 1493),
#  ('runner', 1490),
#  ('nhân vật', 1478),
#  ('chủ tịch', 1475),
#  ('trở lại', 1465),
#  ('hcm', 1463),
#  ('thi đấu', 1458),
#  ('thì', 1442),
#  ('biển', 1442),
#  ('quá trình', 1439),
#  ('làm việc', 1433),
#  ('mục tiêu', 1428),
#  ('quan trọng', 1422),
#  ('thường', 1421),
#  ('bản', 1409),
#  ('phía', 1400),
#  ('chọn', 1397),
#  ('xã hội', 1396),
#  ('đức', 1395),
#  ('vấn đề', 1393),
#  ('rồi', 1392),
#  ('mạnh', 1388),
#  ('vậy', 1380),
#  ('năm ngoái', 1380),
#  ('nguồn', 1379),
#  ('1', 1378),
#  ('nhật', 1375),
#  ('đất', 1374),
#  ('vnexpress', 1366),
#  ('2022', 1363),
#  ('chính sách', 1360),
#  ('đặt', 1356),
#  ('vai', 1349),
#  ('ngay', 1347),
#  ('học', 1347),
#  ('6', 1346),
#  ('ukraine', 1338),
#  ('đủ', 1333),
#  ('khó', 1332),
#  ('alcaraz', 1331),
#  ('kỷ lục', 1329),
#  ('đua', 1325),
#  ('hướng', 1325),
#  ('set', 1324),
#  ('vài', 1321),
#  ('hồi', 1316),
#  ('thành công', 1316),
#  ('vđv', 1313),
#  ('đại học', 1310),
#  ('thành phố', 1307),
#  ('khó khăn', 1303),
#  ('đông', 1301),
#  ('cậu', 1289),
#  ('sự kiện', 1287),
#  ('30', 1280),
#  ('quyết định', 1271),
#  ('môi trường', 1265),
#  ('chung kết', 1255),
#  ('nhằm', 1252),
#  ('đối thủ', 1250),
#  ('tây', 1249),
#  ('chiếc', 1244),
#  ('sáng', 1241),
#  ('vừa', 1239),
#  ('năng lượng', 1229),
#  ('vàng', 1226),
#  ('vị trí', 1225),
#  ('chính phủ', 1223),
#  ('đặc biệt', 1222),
#  ('ghi', 1221),
#  ('đồng thời', 1221),
#  ('clb', 1220),
#  ('lấy', 1215),
#  ('khoản', 1206),
#  ('dành', 1206),
#  ('chia sẻ', 1197),
#  ('cổ phiếu', 1194),
#  ('nó', 1177),
#  ('tiền đạo', 1176),
#  ('nghĩ', 1173),
#  ('dẫn', 1170),
#  ('trường', 1170),
#  ('giai đoạn', 1169),
#  ('ảnh hưởng', 1163),
#  ('thể hiện', 1162),
#  ('thay đổi', 1159),
#  ('vùng', 1159),
#  ('chuyến', 1158),
#  ('lời', 1158),
#  ('tổng thống', 1157),
#  ('thấp', 1148),
#  ('tài chính', 1147),
#  ('chị', 1147),
#  ('nhanh', 1142),
#  ('đá', 1141),
#  ('chi', 1140),
#  ('cấp', 1139),
#  ('chủ', 1137),
#  ('quay', 1137),
#  ('kế hoạch', 1130),
#  ('xuất hiện', 1129),
#  ('–', 1125),
#  ('sinh', 1123),
#  ('kinh doanh', 1123),
#  ('thành tích', 1121),
#  ('mẹ', 1121),
#  ('châu âu', 1116),
#  ('giám đốc', 1114),
#  ('chuyển', 1111),
#  ('ăn', 1110),
#  ('lĩnh vực', 1110),
#  ('trang', 1105),
#  ('nữ', 1101),
#  ('hợp đồng', 1095),
#  ('nữa', 1092),
#  ('buổi', 1091),
#  ('quy nhơn', 1086),
#  ('ca sĩ', 1085),
#  ('cuộc sống', 1080),
#  ('sớm', 1077),
#  ('ứng dụng', 1075),
#  ('thanh', 1073),
#  ('loạt', 1072),
#  ('thông qua', 1071),
#  ('sách', 1071),
#  ('áo', 1069),
#  ('cú', 1064),
#  ('quy định', 1061),
#  ('ra mắt', 1055),
#  ('city', 1054),
#  ('thi', 1054),
#  ('quản lý', 1049),
#  ('bay', 1049),
#  ('giới', 1048),
#  ('trung tâm', 1037),
#  ('hết', 1035),
#  ('công bố', 1034),
#  ('tỉnh', 1034),
#  ('thiếu', 1032),
#  ('kỳ', 1024),
#  ('tập', 1023),
#  ('ngân hàng', 1023),
#  ('bản thân', 1022),
#  ('quỹ', 1022),
#  ('dân', 1022),
#  ('phù hợp', 1020),
#  ('grand', 1020),
#  ('đôi', 1017),
#  ('thế', 1014),
#  ('chi phí', 1009),
#  ('m', 1007),
#  ('hát', 1006),
#  ('đại diện', 1004),
#  ('nước ngoài', 999),
#  ('mở rộng', 999),
#  ('toàn cầu', 998),
#  ('ít', 996),
#  ('phát hiện', 996),
#  ('slam', 996),
#  ('sáng tạo', 995),
#  ('chung', 989),
#  ('12', 988),
#  ('văn', 985),
#  ('nghệ sĩ', 983),
#  ('thiết bị', 982),
#  ('nâng', 981),
#  ('nền', 981),
#  ('nợ', 981),
#  ('15', 980),
#  ('dự', 980),
#  ('nhìn', 980),
#  ('quan hệ', 978),
#  ('21', 970),
#  ('nổi tiếng', 969),
#  ('tập trung', 967),
#  ('giống', 966),
#  ('đơn vị', 964),
#  ('yêu cầu', 955),
#  ('tự', 955),
#  ('nhạc', 955),
#  ('chuyên gia', 954),
#  ('2021', 950),
#  ('tay', 949),
#  ('nằm', 948),
#  ('bước', 947),
#  ('cảnh', 946),
#  ('sự nghiệp', 944),
#  ('tranh', 938),
#  ('chúng', 938),
#  ('phiên', 938),
#  ('bảng', 930),
#  ('mở', 930),
#  ('world', 926),
#  ('riêng', 924),
#  ('thành viên', 923),
#  ('thật', 922),
#  ('league', 922),
#  ('dự kiến', 920),
#  ('chiều', 917),
#  ('gọi', 913),
#  ('hè', 911),
#  ('màu', 911),
#  ('địa phương', 911),
#  ('cung cấp', 910),
#  ('7', 908),
#  ('vợ', 901),
#  ('cơ quan', 901),
#  ('hồng', 900),
#  ('bắc', 895),
#  ('bỏ', 893),
#  ('phòng', 892),
#  ('psg', 891),
#  ('bảo vệ', 891),
#  ('nội', 888),
#  ('bất động sản', 886),
#  ('khỏi', 886),
#  ('mbappe', 884),
#  ('phân tích', 883),
#  ('suốt', 882),
#  ('lãnh đạo', 881),
#  ('thông tin', 877),
#  ('lãi suất', 876),
#  ('điều kiện', 875),
#  ('thời', 875),
#  ('vụ', 875),
#  ('quan tâm', 875),
#  ('ngọc', 874),
#  ('đảm bảo', 872),
#  ('hiện tại', 868),
#  ('lịch sử', 868),
#  ('tất cả', 867),
#  ('chân', 866),
#  ('tương lai', 865),
#  ('công việc', 865),
#  ('thông báo', 864),
#  ('nội dung', 864),
#  ('cannes', 864),
#  ('danh hiệu', 863),
#  ('nhà đầu tư', 862),
#  ('mặt trời', 861),
#  ('trả', 860),
#  ('tốc độ', 858),
#  ('em', 858),
#  ('thương mại', 857),
#  ('đoàn', 854),
#  ('ấn', 854),
#  ('lao động', 854),
#  ('kong', 853),
#  ('sáu', 851),
#  ('đội tuyển', 851),
#  ('thái', 849),
#  ('giá trị', 848),
#  ('kiểm soát', 846),
#  ('cũ', 846),
#  ('xa', 845),
#  ('nhà nước', 843),
#  ('dòng', 842),
#  ('cựu', 840),
#  ('vật liệu', 840),
#  ('cái', 839),
#  ('2018', 837),
#  ('nhu cầu', 836),
#  ('chúng ta', 834),
#  ('hong', 834),
#  ('hỏi', 832),
#  ('đầm', 832),
#  ('top', 830),
#  ('chiến thắng', 830),
#  ('dịch vụ', 829),
#  ('mô hình', 828),
#  ('mối', 827),
#  ('40', 827),
#  ('hoàn thành', 825),
#  ('cá nhân', 823),
#  ('lương', 822),
#  ('nhà khoa học', 820),
#  ('xảy', 819),
#  ('cầu', 819),
#  ('sâu', 816),
#  ('tấn công', 812),
#  ('hợp tác', 810),
#  ('sức', 809),
#  ('2019', 808),
#  ('thời điểm', 808),
#  ('an toàn', 807),
#  ('tối', 806),
#  ('xanh', 806),
#  ('máy', 805),
#  ('quý', 802),
#  ('hạ', 801),
#  ('đề nghị', 800),
#  ('con người', 799),
#  ('quy mô', 799),
#  ('ngoài ra', 794),
#  ('hiểu', 793),
#  ('vay', 790),
#  ('phạm', 788),
#  ('trải', 788),
#  ('thúc đẩy', 788),
#  ('chuyện', 787),
#  ('liên quan', 785),
#  ('thậm chí', 785),
#  ('tuyển', 783),
#  ('hiệu quả', 782),
#  ('tổng', 782),
#  ('văn hóa', 782),
#  ('liên tục', 781),
#  ('điện ảnh', 781),
#  ('tập đoàn', 779),
#  ('16', 778),
#  ('thích', 778),
#  ('chồng', 778),
#  ('minh', 777),
#  ('công', 774),
#  ('trái', 769),
#  ('đoạt', 765),
#  ('giải pháp', 764),
#  ('giao dịch', 763),
#  ('hình ảnh', 762),
#  ('rời', 761),
#  ('bảy', 760),
#  ('nỗ lực', 759),
#  ('đẹp', 759),
#  ('video', 758),
#  ('đúng', 755),
#  ('100', 754),
#  ('đen', 754),
#  ('câu chuyện', 753),
#  ('thay', 752),
#  ('trải nghiệm', 751),
#  ('xử lý', 751),
#  ('siêu', 749),
#  ('nhận xét', 747),
#  ('11', 746),
#  ('chuẩn bị', 746),
#  ('kỳ vọng', 745),
#  ('công nghiệp', 745),
#  ('giây', 742),
#  ('tăng trưởng', 742),
#  ('vũ trụ', 741),
#  ('caesar', 738),
#  ('an', 737),
#  ('khẳng định', 736),
#  ('chất lượng', 736),
#  ('thương hiệu', 736),
#  ('khu', 734),
#  ('hạn chế', 732),
#  ('roland', 732),
#  ('viện', 731),
#  ('kỹ thuật', 729),
#  ('cơ sở', 729),
#  ('tiếp', 723),
#  ('ấn tượng', 723),
#  ('hôm nay', 723),
#  ('quốc hội', 722),
#  ('đối với', 719),
#  ('dần', 719),
#  ('đích', 718),
#  ('dự báo', 717),
#  ('cuối cùng', 715),
#  ('real', 714),
#  ('thử nghiệm', 714),
#  ('báo', 713),
#  ('of', 712),
#  ('trung', 711),
#  ('50', 711),
#  ('chịu', 708),
#  ('thu hút', 708),
#  ('8', 707),
#  ('hoàng', 707),
#  ('duy trì', 707),
#  ('gửi', 706),
#  ('khá', 702),
#  ('quả', 700),
#  ('18', 700),
#  ('cạnh', 700),
#  ('garros', 700),
#  ('bộ trưởng', 700),
#  ('pin', 699),
#  ('chất', 698),
#  ('tác giả', 697),
#  ('new', 696),
#  ('anh hùng', 696),
#  ('thể thao', 694),
#  ('lẫn', 694),
#  ('rõ', 694),
#  ('rút', 693),
#  ('nhiệm vụ', 691),
#  ('lực lượng', 690),
#  ('nhà máy', 690),
#  ('khách hàng', 689),
#  ('đánh', 687),
#  ('dữ liệu', 687),
#  ('du lịch', 686),
#  ('hành động', 686),
#  ('lập', 685),
#  ('ký', 684),
#  ('bao gồm', 682),
#  ('tác động', 682),
#  ('bán kết', 680),
#  ('phong cách', 676),
#  ('tuấn', 675),
#  ('đồ', 675),
#  ('khách', 675),
#  ('không gian', 672),
#  ('câu', 669),
#  ('pha', 666),
#  ('kết hợp', 666),
#  ('ngôi', 666),
#  ('báo cáo', 666),
#  ('hàng đầu', 664),
#  ('màn', 664),
#  ('tài tử', 664),
#  ('cự ly', 661),
#  ('h', 660),
#  ('giải thưởng', 657),
#  ('tự do', 656),
#  ('phát', 656),
#  ('chặng', 653),
#  ('dựa', 652),
#  ('giao', 652),
#  ('hóa', 651),
#  ('tỷ lệ', 649),
#  ('tiền vệ', 648),
#  ('đáng', 648),
#  ('mặt', 648),
#  ('lượng', 647),
#  ('13', 646),
#  ('vai trò', 646),
#  ('y tế', 646),
#  ('thường xuyên', 645),
#  ('tìm kiếm', 645),
#  ('hạng', 644),
#  ('tài sản', 644),
#  ('di chuyển', 643),
#  ('sẵn sàng', 643),
#  ('2020', 641),
#  ('giải quyết', 641),
#  ('trao', 640),
#  ('rủi ro', 639),
#  ('triển khai', 638),
#  ('dễ', 636),
#  ('euro', 636),
#  ('đoạn', 636),
#  ('ngắn', 636),
#  ('champions', 634),
#  ('phương', 634),
#  ('kim', 634),
#  ('bé', 634),
#  ('tinh thần', 633),
#  ('phục vụ', 633),
#  ('phát hành', 632),
#  ('đẩy', 631),
#  ('tạp chí', 631),
#  ('lớp', 631),
#  ('đời', 628),
#  ('bối cảnh', 627),
#  ('toàn', 627),
#  ('phá', 626),
#  ('cạnh tranh', 626),
#  ('liên tiếp', 625),
#  ('game', 625),
#  ('titan', 624),
#  ('lãi', 621),
#  ('ngày càng', 621),
#  ('tay đua', 621),
#  ('hà nội', 620),
#  ('châu á', 620),
#  ('utd', 620),
#  ('trắng', 620),
#  ('a', 618),
#  ('kết thúc', 617),
#  ('chiến lược', 616),
#  ('toàn bộ', 615),
#  ('tám', 615),
#  ('tầm', 614),
#  ('tấn', 612),
#  ('người đẹp', 612),
#  ('italy', 611),
#  ('nole', 609),
#  ('mời', 608),
#  ('9', 608),
#  ('càng', 608),
#  ('thăm', 608),
#  ('cải thiện', 607),
#  ('thế nào', 607),
#  ('nhận định', 607),
#  ('25', 607),
#  ('luật', 607),
#  ('chú ý', 604),
#  ('sao', 604),
#  ('niềm', 603),
#  ('lối', 602),
#  ('quanh', 602),
#  ('chết', 601),
#  ('thực tế', 601),
#  ('hy vọng', 600),
#  ('cố gắng', 598),
#  ('kinh nghiệm', 597),
#  ('thất bại', 596),
#  ('áp lực', 595),
#  ('chủ yếu', 595),
#  ('sức khỏe', 595),
#  ('vũ', 594),
#  ('nhân viên', 594),
#  ('nghe', 589),
#  ('cây', 589),
#  ('làng', 587),
#  ('mã', 587),
#  ('đối mặt', 586),
#  ('áp dụng', 585),
#  ('hội', 584),
#  ('musk', 583),
#  ('argentina', 582),
#  ('lần lượt', 581),
#  ('bức', 581),
#  ('mai', 580),
#  ('ổn định', 578),
#  ('nóng', 578),
#  ('nặng', 576),
#  ('chậm', 576),
#  ('tích cực', 575),
#  ('xuất sắc', 575),
#  ('messi', 574),
#  ('đơn', 572),
#  ('đổi mới', 571),
#  ('23', 569),
#  ('âm nhạc', 569),
#  ('gió', 568),
#  ('fed', 568),
#  ('vì thế', 567),
#  ('vỡ', 564),
#  ('barca', 563),
#  ('họp', 563),
#  ('lợi nhuận', 563),
#  ('long', 563),
#  ('ngân sách', 563),
#  ('ngôi sao', 562),
#  ('rộng', 562),
#  ('theo dõi', 561),
#  ('loan', 561),
#  ('sinh viên', 561),
#  ('ta', 559),
#  ('australia', 558),
#  ('gấp', 558),
#  ('tỷ số', 557),
#  ('ghi nhận', 557),
#  ('song', 555),
#  ('loài', 555),
#  ('nhớ', 554),
#  ('tiến', 553),
#  ('nhanh chóng', 552),
#  ('doanh thu', 551),
#  ('tương tự', 551),
#  ('sợi', 549),
#  ('tiếp cận', 549),
#  ('sân khấu', 549),
#  ('vua', 548),
#  ('chứng khoán', 548),
#  ('lượt', 546),
#  ('công trình', 544),
#  ('an ninh', 544),
#  ('đêm', 543),
#  ('na', 543),
#  ('nghệ thuật', 543),
#  ('ca khúc', 543),
#  ('sở hữu', 541),
#  ('17', 541),
#  ('tiếp theo', 539),
#  ('14', 538),
#  ('hoàn toàn', 538),
#  ('lý do', 537),
#  ('không khí', 537),
#  ('lê', 535),
#  ('sàn', 535),
#  ('lựa chọn', 534),
#  ('hải', 533),
#  ('tình trạng', 533),
#  ('chiếm', 532),
#  ('mẫu', 531),
#  ('dừng', 531),
#  ('thu nhập', 529),
#  ('tham dự', 529),
#  ('vui', 529),
#  ('nửa', 529),
#  ('giới thiệu', 529),
#  ('vẽ', 529),
#  ('tòa', 529),
#  ('yếu tố', 528),
#  ('thời tiết', 528),
#  ('lâm', 526),
#  ('show', 526),
#  ('lạm phát', 524),
#  ('tiêu dùng', 523),
#  ('ban đầu', 521),
#  ('hồ', 521),
#  ('yêu', 520),
#  ('bệnh', 518),
#  ('xe điện', 518),
#  ('chuyển nhượng', 517),
#  ('ủng hộ', 517),
#  ('trung bình', 516),
#  ('hòa', 515),
#  ('rơi', 515),
#  ('chỉ số', 515),
#  ('kém', 514),
#  ('trở nên', 513),
#  ('họa sĩ', 512),
#  ('cảm thấy', 510),
#  ('nhà sản xuất', 510),
#  ('mảng', 510),
#  ('cha', 509),
#  ('mạng', 509),
#  ('quân đội', 509),
#  ('xuất phát', 508),
#  ('chuỗi', 508),
#  ('trực tiếp', 507),
#  ('máy bay', 507),
#  ('bloomberg', 507),
#  ('quân', 505),
#  ('truyền thông', 505),
#  ('cho phép', 504),
#  ('tiết lộ', 504),
#  ('nắng', 504),
#  ('thuê', 503),
#  ('thực sự', 502),
#  ('góc', 501),
#  ('de', 501),
#  ('chăm sóc', 501),
#  ('hạt giống', 501),
#  ('chiếu', 501),
#  ('ôtô', 501),
#  ('giao hữu', 500),
#  ('điều hành', 500),
#  ('khai thác', 498),
#  ('sáng tác', 498),
#  ('thành lập', 497),
#  ('lễ', 496),
#  ('gốc', 496),
#  ('in', 496),
#  ('tuyến', 495),
#  ('chỗ', 495),
#  ('con trai', 495),
#  ('cộng đồng', 494),
#  ('duy', 493),
#  ('tránh', 492),
#  ('ánh sáng', 492),
#  ('miền', 492),
#  ('góp mặt', 491),
#  ('quyền', 490),
#  ('quan điểm', 490),
#  ('hiện đại', 489),
#  ('cung', 489),
#  ('nhiệt độ', 489),
#  ('cuốn', 488),
#  ('kết nối', 487),
#  ('chấp nhận', 485),
#  ('hiệp', 485),
#  ('ngoại hạng', 485),
#  ('phương pháp', 485),
#  ('cảm xúc', 485),
#  ('thưởng', 484),
#  ('tình yêu', 484),
#  ('nhì', 484),
#  ('giày', 483),
#  ('giọng', 483),
#  ('trạm', 482),
#  ('19', 481),
#  ('thay vì', 481),
#  ('la', 481),
#  ('số lượng', 481),
#  ('ly', 480),
#  ('chấn thương', 480),
#  ('mặc', 480),
#  ('xếp', 479),
#  ('đà', 477),
#  ('bao giờ', 477),
#  ('bóng đá', 476),
#  ('phó', 476),
#  ('hiện nay', 476),
#  ('kéo dài', 475),
#  ('trả lời', 475),
#  ('phần lớn', 474),
#  ('dẫn dắt', 473),
#  ('chống', 473),
#  ('tàu lặn', 473),
#  ('xác định', 471),
#  ('76', 471),
#  ('chụp', 471),
#  ('cá', 471),
#  ('đọc', 471),
#  ('tập luyện', 470),
#  ('kéo', 470),
#  ('tự nhiên', 470),
#  ('thoải mái', 469),
#  ('vé', 469),
#  ('khí hậu', 466),
#  ('tuyên bố', 465),
#  ('trình diễn', 464),
#  ('kịch bản', 464),
#  ('lưới', 463),
#  ('2024', 463),
#  ('đài', 463),
#  ('ghi bàn', 462),
#  ('yoon', 461),
#  ('ủy ban', 460),
#  ('tiềm năng', 459),
#  ('số một', 459),
#  ('dạng', 458),
#  ('vận hành', 458),
#  ('đăng ký', 458),
#  ('reuters', 458),
#  ('dễ dàng', 457),
#  ('coi', 457),
#  ('ngồi', 456),
#  ('nhựa', 456),
#  ('lâu', 455),
#  ('tình hình', 455),
#  ...]

# %%
def read_stopwords(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        stopwords = set(file.read().splitlines())
    return stopwords


stopwords_file_path = 'vietnamese-stopwords.txt'
stopwords = read_stopwords(stopwords_file_path)


print(stopwords)
# Out:
# {'nghĩ đến', 'nói rõ', 'bác', 'khác nào', 'nơi nơi', 'tăng', 'cùng cực', 'mọi giờ', 'không hay', 'số là', 'thế nào', 'chẳng phải', 'nghiễm nhiên', 'biết mình', 'ừ ừ', 'xa cách', 'thật ra', 'phải không', 'lại nói', 'thật lực', 'căn', 'rén', 'bằng như', 'khi nào', 'vừa lúc', 'hiện nay', 'vốn dĩ', 'khỏi', 'tuy có', 'nhằm', 'đối với', 'ơi là', 'sau này', 'ít quá', 'lần', 'như', 'cả nghe', 'vừa', 'cao thấp', 'nó', 'không tính', 'thế à', 'ô kê', 'chớ không', 'nhỡ ra', 'ở đây', 'dầu sao', 'lúc sáng', 'nhận họ', 'nói nhỏ', 'với', 'nhận thấy', 'nhằm khi', 'thấp xuống', 'xem lại', 'nhiệt liệt', 'cách đều', 'sao bằng', 'ngoài này', 'gây thêm', 'nặng về', 'lấy vào', 'bất thình lình', 'mọi lúc', 'tỏ vẻ', 'ngoài ra', 'họ', 'mà', 'tăng chúng', 'ầu ơ', 'thường', 'bớ', 'nói riêng', 'tuổi', 'tại', 'bây chừ', 'rón rén', 'đơn vị', 'làm cho', 'trệu trạo', 'vì thế', 'thời gian sử dụng', 'bấy chầy', 'trước hết', 'hỏi lại', 'bỏ xa', 'bấy lâu nay', 'từng đơn vị', 'từng ấy', 'tấm bản', 'vị tất', 'từ tính', 'tìm hiểu', 'đúng ngày', 'như sau', 'phần nào', 'bất kỳ', 'trở thành', 'đâu có', 'thà là', 'thế là', 'cùng tột', 'úi', 'tuốt luốt', 'mọi sự', 'hơn', 'sắp', 'thế sự', 'quan trọng vấn đề', 'nhằm vào', 'nếu như', 'hỗ trợ', 'khác thường', 'thực vậy', 'bấy', 'bằng nhau', 'hơn là', 'ví bằng', 'nhờ nhờ', 'so với', 'tránh khỏi', 'chị', 'thỉnh thoảng', 'vả chăng', 'từ', 'hay không', 'như trên', 'lấy xuống', 'bập bõm', 'là là', 'tại vì', 'cái đã', 'phần', 'không thể', 'tôi con', 'tiếp đó', 'ngày cấp', 'phứt', 'âu là', 'dù cho', 'dài lời', 'răng răng', 'bản ý', 'cô quả', 'lâu lâu', 'khi không', 'nếu có', 'mỗi ngày', 'bà ấy', 'bên bị', 'tháng', 'trước sau', 'ngăn ngắt', 'như là', 'nhân dịp', 'dần dà', 'dù rằng', 'sáng ngày', 'lại cái', 'thi thoảng', 'hay hay', 'ý hoặc', 'càng hay', 'thái quá', 'cứ như', 'thuộc cách', 'ứ ừ', 'bây bẩy', 'ngày tháng', 'ngay bây giờ', 'căn cái', 'cơ mà', 'đầu tiên', 'thường thường', 'lại ăn', 'thật thà', 'thực tế', 'chỉn', 'lại quả', 'biết đâu', 'chứ', 'mọi người', 'ủa', 'khoảng không', 'tênh tênh', 'thêm vào', 'ái chà', 'quá bộ', 'được cái', 'do đó', 'là', 'gây', 'đưa chuyện', 'quay số', 'sau đó', 'song le', 'vì rằng', 'dù', 'được lời', 'nhận làm', 'ngay khi đến', 'tránh ra', 'phải tay', 'ngay', 'để mà', 'thì', 'đâu như', 'ren rén', 'đủ điều', 'giá trị', 'rốt cục', 'ngồi', 'thà rằng', 'chắc lòng', 'béng', 'ớ này', 'ít khi', 'dù sao', 'biết việc', 'chớ', 'lấy giống', 'quá mức', 'bển', 'trước nhất', 'nhận nhau', 'ai', 'hoàn toàn', 'nhất nhất', 'đây này', 'bằng nào', 'hơn hết', 'thuộc lại', 'ngày nào', 'họ xa', 'veo', 'á', 'nớ', 'nhất là', 'sớm ngày', 'thêm giờ', 'trả ngay', 'bất kì', 'chớ gì', 'chịu', 'công nhiên', 'ồ', 'chưa từng', 'nói trước', 'thấp', 'nhất đán', 'nhà chung', 'đến nỗi', 'nhanh tay', 'khác gì', 'riêng', 'qua tay', 'sau cuối', 'rồi xem', 'buổi làm', 'có chuyện', 'vượt', 'xa tanh', 'lại người', 'nên tránh', 'đến cùng', 'tên chính', 'đủ dùng', 'xem ra', 'lớn', 'phốc', 'luôn', 'thường số', 'có thể', 'lấy ráo', 'bay biến', 'bất tử', 'để cho', 'không bán', 'nào', 'cấp', 'vì chưng', 'thật tốt', 'giá trị thực tế', 'phải rồi', 'tấm', 'cây', 'tháng ngày', 'thậm', 'những ai', 'đến nơi', 'bởi thế cho nên', 'tay', 'từ tại', 'dù gì', 'nhất mực', 'nói tốt', 'tìm việc', 'ăn quá', 'trong lúc', 'ông', 'hết ý', 'bằng không', 'một lúc', 'thậm cấp', 'rằng', 'vài tên', 'thếch', 'xuất hiện', 'lời nói', 'như trước', 'không phải', 'không ngoài', 'chung quy', 'thường đến', 'đâu đâu', 'chọn ra', 'ừ', 'làm dần dần', 'dễ dùng', 'duy', 'bỏ lại', 'lời chú', 'này', 'tiếp theo', 'hết rồi', 'những muốn', 'sang năm', 'tới mức', 'tấn', 'mở nước', 'trong khi', 'ơ kìa', 'phỉ phui', 'vừa mới', 'cái gì', 'đầy năm', 'từ điều', 'đến thì', 'đến bao giờ', 'sao', 'khó chơi', 'úi chà', 'có ai', 'trên bộ', 'ăn riêng', 'đến thế', 'thốc tháo', 'làm tăng', 'lại đây', 'nước', 'phắt', 'phần nhiều', 'tấm các', 'phụt', 'xa xả', 'nền', 'trực tiếp', 'dùng làm', 'vâng vâng', 'bài bỏ', 'năm', 'xin', 'sắp đặt', 'phần sau', 'ông ổng', 'nên người', 'cũng', 'chắc dạ', 'đưa em' ...

# %% [markdown]
# Loại bỏ stopword

# %%
def remove_stopwords(texts, stopwords):
    filtered_texts = []
    for text in texts:
        words = text.split()
        filtered_words = [word for word in words if word not in stopwords]
        filtered_text = ' '.join(filtered_words)
        filtered_texts.append(filtered_text)
    return filtered_texts
filtered_texts = remove_stopwords(texts, stopwords)

# %% [markdown]
# ### III. Xây dựng mô hình, chia tập train và test

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
test_percent = 0.2
X_train, X_test, y_train, y_test = train_test_split(texts, tags, test_size=test_percent, random_state=42)

# encode label
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
print(list(label_encoder.classes_), '\n')
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)
# Out:
# ['Giải trí', 'Khoa học', 'Kinh tế', 'Thế giới', 'Thể thao', 'Thời sự']

# %%
MODEL_PATH = "models"

import os
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)

# %% [markdown]
# ### Naive Bayes

# %%
import pickle
import time
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

start_time = time.time()
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,1),
                                             max_df=0.8,
                                             max_features=None)), 
                     ('tfidf', TfidfTransformer()), 
                     ('clf', MultinomialNB())
                    ])
text_clf = text_clf.fit(X_train, y_train)

train_time = time.time() - start_time
print('Done training Naive Bayes in', train_time, 'seconds.')

# Save model
pickle.dump(text_clf, open(os.path.join(MODEL_PATH, "naive_bayes.pkl"), 'wb'))
# Out:
# Done training Naive Bayes in 1.3793132305145264 seconds.

# %% [markdown]
# ### Linear Classifier

# %%
from sklearn.linear_model import LogisticRegression
    
start_time = time.time()
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,1),
                                             max_df=0.8,
                                             max_features=None)), 
                     ('tfidf', TfidfTransformer()),
                     ('clf', LogisticRegression(solver='lbfgs', 
                                                multi_class='auto',
                                                max_iter=10000))
                    ])
text_clf = text_clf.fit(X_train, y_train)

train_time = time.time() - start_time
print('Done training Linear Classifier in', train_time, 'seconds.')

# Save model
pickle.dump(text_clf, open(os.path.join(MODEL_PATH, "linear_classifier.pkl"), 'wb'))
# Out:
# Done training Linear Classifier in 2.7300045490264893 seconds.

# %% [markdown]
# ### SVM - Support Vector Machine

# %%
from sklearn.svm import SVC

start_time = time.time()
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,1),
                                             max_df=0.8,
                                             max_features=None)), 
                     ('tfidf', TfidfTransformer()),
                     ('clf', SVC(gamma='scale'))
                    ])
text_clf = text_clf.fit(X_train, y_train)

train_time = time.time() - start_time
print('Done training SVM in', train_time, 'seconds.')

# Save model
pickle.dump(text_clf, open(os.path.join(MODEL_PATH, "svm.pkl"), 'wb'))
# Out:
# Done training SVM in 13.578113079071045 seconds.

# %% [markdown]
# ### Độ chính xác của các mô hình

# %%
# Naive Bayes
model = pickle.load(open(os.path.join(MODEL_PATH,"naive_bayes.pkl"), 'rb'))
y_pred = model.predict(X_test)
print('Naive Bayes, Accuracy =', np.mean(y_pred == y_test))

# Linear Classifier
model = pickle.load(open(os.path.join(MODEL_PATH,"linear_classifier.pkl"), 'rb'))
y_pred = model.predict(X_test)
print('Linear Classifier, Accuracy =', np.mean(y_pred == y_test))

# SVM
model = pickle.load(open(os.path.join(MODEL_PATH,"svm.pkl"), 'rb'))
y_pred = model.predict(X_test)
print('SVM, Accuracy =', np.mean(y_pred == y_test))
# Out:
# Naive Bayes, Accuracy = 0.9026248941574937
# Linear Classifier, Accuracy = 0.9898391193903472
# SVM, Accuracy = 0.9940728196443692

# %% [markdown]
# ### Kết quả từng phần

# %%
from sklearn.metrics import classification_report

nb_model = pickle.load(open(os.path.join(MODEL_PATH,"svm.pkl"), 'rb'))
y_pred = nb_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=list(label_encoder.classes_)))
# Out:
#               precision    recall  f1-score   support
#
#     Giải trí       0.99      1.00      1.00       327
#     Khoa học       0.98      1.00      0.99       194
#      Kinh tế       1.00      1.00      1.00       176
#     Thế giới       0.98      0.98      0.98        65
#     Thể thao       1.00      1.00      1.00       359
#      Thời sự       1.00      0.92      0.96        60
#
#     accuracy                           0.99      1181
#    macro avg       0.99      0.98      0.99      1181
# weighted avg       0.99      0.99      0.99      1181
